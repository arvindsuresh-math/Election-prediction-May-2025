# %%
import os
import pandas as pd
import numpy as np
import json
import optuna
import xgboost as xgb
import ast
import time
from sklearn.model_selection import ParameterGrid
from typing import List, Dict, Union, Tuple

from constants import MODELS_DIR, RESULTS_DIR, PREDS_DIR, DEVICE
from data_handling import DataHandler # For type hinting
from metrics import softmax, weighted_softprob_obj, weighted_cross_entropy_eval # Import metrics
from optuna.integration import XGBoostPruningCallback
# Out:
# Using MPS device (Apple Silicon GPU)

# %%
def xgb_pruning_callback(trial, metric_name='weighted-CE'):
    """
    Creates a pruning callback function for XGBoost that reports mean validation 
    loss across all folds to Optuna at each boosting round. Returns a callback function compatible with xgb.cv()
    """
    def callback(env):
        current_round = env.iteration # Current boosting round
        mean_val_loss = env.evaluation_result_list[f'test-{metric_name}-mean'][current_round]
        
        # Report + pruning check
        trial.report(mean_val_loss, step=current_round)
        if trial.should_prune():
            raise optuna.exceptions.TrialPruned()
            
    return callback

# %%
def objective_xgb(trial: optuna.trial.Trial, 
                  dtrain: xgb.DMatrix,
                  num_boost_rounds: int = 150,
                  early_stopping_rounds: int = 30):
    """
    Objective function for XGBoost hyperparameter optimization using Optuna. Uses weighted_softprob_obj and weighted_cross_entropy_eval as custom objective and evaluation metric. Returns the mean val loss for the trial.
    """
    # Get hyperparams for the current trial
    params = {
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3, log=True),
        'gamma': trial.suggest_float('gamma', 0.0, 5.0, log=False),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0, log=False),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.4, 1.0, log=False),
        'colsample_bylevel': trial.suggest_float('colsample_bylevel', 0.4, 1.0, log=False),
        'colsample_bynode': trial.suggest_float('colsample_bynode', 0.4, 1.0, log=False),
        'reg_alpha': trial.suggest_float('reg_alpha', 1e-8, 10.0, log=True),
        'reg_lambda': trial.suggest_float('reg_lambda', 1e-8, 10.0, log=True),
        'max_depth': trial.suggest_int('max_depth', 3, 12, step=1),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 20, step=1)
    }
    
    # Create pruning callback
    pruning_callback = XGBoostPruningCallback(trial, "test-weighted-CE")
    
    # Run cross-validation
    cv_results = xgb.cv(
        params=params,
        dtrain=dtrain,
        num_boost_round=num_boost_rounds,
        nfold=3,
        obj=weighted_softprob_obj, #custom objective
        custom_metric=weighted_cross_entropy_eval, #custom eval, name='weighted-CE'
        maximize=False,
        early_stopping_rounds=early_stopping_rounds,
        callbacks=[pruning_callback],
        verbose_eval=False,
        shuffle=False # Ensures folds match what's used by other models
    )
    
    # Return best validation score
    best_score = cv_results['test-weighted-CE-mean'].min()
    return best_score

# %%
dh = DataHandler()
# Out:
# DataHandler initialized - Using 114 features - Test year: 2020

# %%
asha_pruner = optuna.pruners.SuccessiveHalvingPruner(
    min_resource=30,        # Minimum number of steps before pruning
    reduction_factor=2,    # Reduction factor for successive halving
    min_early_stopping_rate=0
)

# %%
study_xgb = optuna.create_study(study_name='xgb',
                                direction='minimize',
                                pruner=asha_pruner)
# Out:
# [I 2025-05-10 18:55:34,282] A new study created in memory with name: xgb

# %%
study_xgb.optimize(
    lambda trial: objective_xgb(
        trial,
        dtrain=dh.get_xgb_data('cv'),
        num_boost_rounds=150,
        early_stopping_rounds=50
    ),
    n_trials=128,
    timeout=1200,  
    n_jobs=-1)
# Out:
# [I 2025-05-10 18:55:36,989] Trial 5 pruned. Trial was pruned at iteration 30.
# [I 2025-05-10 18:55:37,353] Trial 3 pruned. Trial was pruned at iteration 30.
# [I 2025-05-10 18:55:37,361] Trial 0 pruned. Trial was pruned at iteration 30.
# [I 2025-05-10 18:55:38,197] Trial 4 pruned. Trial was pruned at iteration 30.
# [I 2025-05-10 18:55:38,821] Trial 6 pruned. Trial was pruned at iteration 30.
# [I 2025-05-10 18:55:39,014] Trial 7 pruned. Trial was pruned at iteration 60.
# [I 2025-05-10 18:55:39,027] Trial 2 finished with value: 1.0532096666666666 and parameters: {'learning_rate': 0.28868708991649145, 'gamma': 1.998709717187389, 'subsample': 0.9684527339681692, 'colsample_bytree': 0.520288944698347, 'colsample_bylevel': 0.9503962537459164, 'colsample_bynode': 0.7284891893907427, 'reg_alpha': 0.017156924784588613, 'reg_lambda': 5.254791852074559e-06, 'max_depth': 6, 'min_child_weight': 18}. Best is trial 2 with value: 1.0532096666666666.
# [I 2025-05-10 18:55:39,665] Trial 1 finished with value: 1.0567983333333333 and parameters: {'learning_rate': 0.28033742170528114, 'gamma': 3.9478085188250227, 'subsample': 0.5696124770332178, 'colsample_bytree': 0.5859408793502769, 'colsample_bylevel': 0.41909682724796005, 'colsample_bynode': 0.4940085048010394, 'reg_alpha': 4.7298104254424084e-05, 'reg_lambda': 1.2339258880205868e-06, 'max_depth': 7, 'min_child_weight': 1}. Best is trial 2 with value: 1.0532096666666666.
# [I 2025-05-10 18:55:39,916] Trial 8 pruned. Trial was pruned at iteration 30.
# [I 2025-05-10 18:55:40,760] Trial 9 pruned. Trial was pruned at iteration 30.
# [I 2025-05-10 18:55:41,641] Trial 12 pruned. Trial was pruned at iteration 30.
# [I 2025-05-10 18:55:42,199] Trial 14 pruned. Trial was pruned at iteration 30.
# [I 2025-05-10 18:55:42,310] Trial 13 pruned. Trial was pruned at iteration 30.
# [I 2025-05-10 18:55:43,252] Trial 10 finished with value: 1.0527133333333334 and parameters: {'learning_rate': 0.13721140003175178, 'gamma': 1.5117030741006747, 'subsample': 0.714687398889593, 'colsample_bytree': 0.8627215695948433, 'colsample_bylevel': 0.9727512032071808, 'colsample_bynode': 0.917862050319579, 'reg_alpha': 1.302849113983368, 'reg_lambda': 0.31995522619789835, 'max_depth': 5, 'min_child_weight': 1}. Best is trial 10 with value: 1.0527133333333334.
# [I 2025-05-10 18:55:43,274] Trial 16 pruned. Trial was pruned at iteration 30.
# [I 2025-05-10 18:55:44,089] Trial 11 finished with value: 1.0524259999999999 and parameters: {'learning_rate': 0.10870630887334788, 'gamma': 2.5811543775601327, 'subsample': 0.9957891484481718, 'colsample_bytree': 0.7750286712769249, 'colsample_bylevel': 0.7904854232721857, 'colsample_bynode': 0.8397049637940849, 'reg_alpha': 1.2740996206129958e-07, 'reg_lambda': 0.0016684552412080359, 'max_depth': 3, 'min_child_weight': 4}. Best is trial 11 with value: 1.0524259999999999.
# [I 2025-05-10 18:55:44,866] Trial 15 pruned. Trial was pruned at iteration 30.
# [I 2025-05-10 18:55:45,482] Trial 17 finished with value: 1.0518706666666666 and parameters: {'learning_rate': 0.29133125366526225, 'gamma': 1.4459014208513383, 'subsample': 0.9486553090316138, 'colsample_bytree': 0.48722995214731724, 'colsample_bylevel': 0.9883150212194987, 'colsample_bynode': 0.4113231539638036, 'reg_alpha': 0.36463715984531864, 'reg_lambda': 0.007174106116588631, 'max_depth': 5, 'min_child_weight': 11}. Best is trial 17 with value: 1.0518706666666666.
# [I 2025-05-10 18:55:47,193] Trial 20 finished with value: 1.05268 and parameters: {'learning_rate': 0.2890354368951705, 'gamma': 2.8475939252410227, 'subsample': 0.9866594955310173, 'colsample_bytree': 0.6270433409311336, 'colsample_bylevel': 0.9967674777904236, 'colsample_bynode': 0.4038375863522035, 'reg_alpha': 4.1158539439565494e-05, 'reg_lambda': 0.0017317378393027134, 'max_depth': 6, 'min_child_weight': 13}. Best is trial 17 with value: 1.0518706666666666.
# [I 2025-05-10 18:55:48,574] Trial 18 finished with value: 1.0473233333333332 and parameters: {'learning_rate': 0.27963015027218036, 'gamma': 0.1674822541158183, 'subsample': 0.9866810509510446, 'colsample_bytree': 0.40300167097627415, 'colsample_bylevel': 0.7383394190031258, 'colsample_bynode': 0.441892645385683, 'reg_alpha': 0.10722092917429703, 'reg_lambda': 0.004629612593679413, 'max_depth': 6, 'min_child_weight': 12}. Best is trial 18 with value: 1.0473233333333332.
# [I 2025-05-10 18:55:49,529] Trial 24 pruned. Trial was pruned at iteration 60.
# [I 2025-05-10 18:55:50,108] Trial 21 finished with value: 1.0492670000000002 and parameters: {'learning_rate': 0.2883445987615052, 'gamma': 0.08919897603629878, 'subsample': 0.9796577263561465, 'colsample_bytree': 0.7574333148175881, 'colsample_bylevel': 0.9882790407742662, 'colsample_bynode': 0.4113696414752702, 'reg_alpha': 2.7108743591992983, 'reg_lambda': 0.004798867799496103, 'max_depth': 5, 'min_child_weight': 13}. Best is trial 18 with value: 1.0473233333333332.
# [I 2025-05-10 18:55:53,411] Trial 22 pruned. Trial was pruned at iteration 120.
# [I 2025-05-10 18:55:54,951] Trial 23 pruned. Trial was pruned at iteration 120.
# [I 2025-05-10 18:55:55,636] Trial 26 pruned. Trial was pruned at iteration 120.
# [I 2025-05-10 18:55:57,748] Trial 19 finished with value: 1.0461916666666666 and parameters: {'learning_rate': 0.2969388675822162, 'gamma': 0.060297027080443266, 'subsample': 0.9743205109792953, 'colsample_bytree': 0.42464919732924883, 'colsample_bylevel': 0.7255398922736745, 'colsample_bynode': 0.41297258755678085, 'reg_alpha': 0.05279699224756021, 'reg_lambda': 0.005262541778654599, 'max_depth': 6, 'min_child_weight': 12}. Best is trial 19 with value: 1.0461916666666666.
# [I 2025-05-10 18:56:00,562] Trial 32 pruned. Trial was pruned at iteration 60.
# [I 2025-05-10 18:56:01,553] Trial 25 finished with value: 1.0447790000000001 and parameters: {'learning_rate': 0.2001275032023765, 'gamma': 0.04341569591612249, 'subsample': 0.8999458997452184, 'colsample_bytree': 0.7848977404621623, 'colsample_bylevel': 0.9017149505829741, 'colsample_bynode': 0.4502306589110226, 'reg_alpha': 0.2714478292292715, 'reg_lambda': 0.003239441425504868, 'max_depth': 4, 'min_child_weight': 13}. Best is trial 25 with value: 1.0447790000000001.
# [I 2025-05-10 18:56:03,476] Trial 31 pruned. Trial was pruned at iteration 120.
# [I 2025-05-10 18:56:03,491] Trial 33 finished with value: 1.0484793333333335 and parameters: {'learning_rate': 0.18606760642593403, 'gamma': 0.5046549963649978, 'subsample': 0.9009360352015456, 'colsample_bytree': 0.40356161873307417, 'colsample_bylevel': 0.7206586296585518, 'colsample_bynode': 0.4645735078030088, 'reg_alpha': 0.08541145510292751, 'reg_lambda': 0.00025094716742721674, 'max_depth': 7, 'min_child_weight': 14}. Best is trial 25 with value: 1.0447790000000001.
# [I 2025-05-10 18:56:04,213] Trial 30 pruned. Trial was pruned at iteration 120.
# [I 2025-05-10 18:56:05,889] Trial 34 pruned. Trial was pruned at iteration 60.
# [I 2025-05-10 18:56:07,104] Trial 29 finished with value: 1.045529 and parameters: {'learning_rate': 0.1892047872353748, 'gamma': 0.05311773411157272, 'subsample': 0.900264243474301, 'colsample_bytree': 0.4161144833512786, 'colsample_bylevel': 0.9025081250468964, 'colsample_bynode': 0.4018629581325027, 'reg_alpha': 0.1656870926210899, 'reg_lambda': 0.056718538486985534, 'max_depth': 4, 'min_child_weight': 13}. Best is trial 25 with value: 1.0447790000000001.
# [I 2025-05-10 18:56:07,351] Trial 35 pruned. Trial was pruned at iteration 60.
# [I 2025-05-10 18:56:09,604] Trial 37 pruned. Trial was pruned at iteration 60.
# [I 2025-05-10 18:56:09,752] Trial 36 pruned. Trial was pruned at iteration 60.
# [I 2025-05-10 18:56:10,063] Trial 28 finished with value: 1.0444630000000001 and parameters: {'learning_rate': 0.18710890586240073, 'gamma': 0.00939481431292688, 'subsample': 0.8948279343808926, 'colsample_bytree': 0.4158135757351956, 'colsample_bylevel': 0.6869184650701823, 'colsample_bynode': 0.4029927089803816, 'reg_alpha': 0.19517379708405744, 'reg_lambda': 0.007985441771073562, 'max_depth': 4, 'min_child_weight': 13}. Best is trial 28 with value: 1.0444630000000001.
# [I 2025-05-10 18:56:10,360] Trial 38 pruned. Trial was pruned at iteration 60.
# [I 2025-05-10 18:56:10,608] Trial 27 finished with value: 1.0443963333333335 and parameters: {'learning_rate': 0.17809505482209076, 'gamma': 0.006496839760894935, 'subsample': 0.9080605979863775, 'colsample_bytree': 0.44521113134200047, 'colsample_bylevel': 0.9040628727338442, 'colsample_bynode': 0.40850612670567205, 'reg_alpha': 0.25727630397724943, 'reg_lambda': 0.017078534426415326, 'max_depth': 4, 'min_child_weight': 13}. Best is trial 27 with value: 1.0443963333333335.
# [I 2025-05-10 18:56:11,945] Trial 39 pruned. Trial was pruned at iteration 60.
# [I 2025-05-10 18:56:12,033] Trial 41 pruned. Trial was pruned at iteration 60.
# [I 2025-05-10 18:56:12,124] Trial 40 pruned. Trial was pruned at iteration 60.
# [I 2025-05-10 18:56:12,525] Trial 43 pruned. Trial was pruned at iteration 30.
# [I 2025-05-10 18:56:12,895] Trial 44 pruned. Trial was pruned at iteration 30.
# [I 2025-05-10 18:56:12,968] Trial 45 pruned. Trial was pruned at iteration 30.
# [I 2025-05-10 18:56:13,373] Trial 46 pruned. Trial was pruned at iteration 30.
# [I 2025-05-10 18:56:14,688] Trial 48 pruned. Trial was pruned at iteration 30.
# [I 2025-05-10 18:56:14,785] Trial 47 pruned. Trial was pruned at iteration 30.
# [I 2025-05-10 18:56:15,377] Trial 50 pruned. Trial was pruned at iteration 30.
# [I 2025-05-10 18:56:15,749] Trial 51 pruned. Trial was pruned at iteration 30.
# [I 2025-05-10 18:56:17,649] Trial 55 pruned. Trial was pruned at iteration 30.
# [I 2025-05-10 18:56:19,928] Trial 49 finished with value: 1.0490013333333332 and parameters: {'learning_rate': 0.15001103181980602, 'gamma': 0.304098846339513, 'subsample': 0.938073190672437, 'colsample_bytree': 0.5343177177870764, 'colsample_bylevel': 0.9410283766370359, 'colsample_bynode': 0.512817065262416, 'reg_alpha': 0.8019457975954828, 'reg_lambda': 0.13267015038240365, 'max_depth': 12, 'min_child_weight': 16}. Best is trial 27 with value: 1.0443963333333335.
# [I 2025-05-10 18:56:22,363] Trial 52 pruned. Trial was pruned at iteration 120.
# [I 2025-05-10 18:56:22,466] Trial 53 pruned. Trial was pruned at iteration 120.
# [I 2025-05-10 18:56:23,988] Trial 54 pruned. Trial was pruned at iteration 120.
# [I 2025-05-10 18:56:24,586] Trial 56 pruned. Trial was pruned at iteration 120.
# [I 2025-05-10 18:56:26,396] Trial 57 finished with value: 1.0468376666666666 and parameters: {'learning_rate': 0.11812528437505815, 'gamma': 0.23560282998083348, 'subsample': 0.6270093600113156, 'colsample_bytree': 0.5776184050831961, 'colsample_bylevel': 0.8460206816921092, 'colsample_bynode': 0.5853209140156475, 'reg_alpha': 0.005037105512426733, 'reg_lambda': 0.9387213631546504, 'max_depth': 3, 'min_child_weight': 7}. Best is trial 27 with value: 1.0443963333333335.
# [I 2025-05-10 18:56:28,353] Trial 59 finished with value: 1.0475976666666666 and parameters: {'learning_rate': 0.23594464187726025, 'gamma': 0.1570051432717358, 'subsample': 0.999288678444627, 'colsample_bytree': 0.4295118316430538, 'colsample_bylevel': 0.8373020282082559, 'colsample_bynode': 0.4358997413536583, 'reg_alpha': 0.08448742327427025, 'reg_lambda': 0.017193044270870386, 'max_depth': 5, 'min_child_weight': 13}. Best is trial 27 with value: 1.0443963333333335.
# [I 2025-05-10 18:56:28,814] Trial 42 finished with value: 1.0442223333333331 and parameters: {'learning_rate': 0.24288184277631422, 'gamma': 0.011282077532844534, 'subsample': 0.937335630923724, 'colsample_bytree': 0.4598123786440355, 'colsample_bylevel': 0.8224291092568519, 'colsample_bynode': 0.5503228472524481, 'reg_alpha': 0.02478363987296656, 'reg_lambda': 0.2668905009585234, 'max_depth': 6, 'min_child_weight': 10}. Best is trial 42 with value: 1.0442223333333331.
# [I 2025-05-10 18:56:31,132] Trial 65 pruned. Trial was pruned at iteration 30.
# [I 2025-05-10 18:56:32,288] Trial 61 finished with value: 1.0463406666666666 and parameters: {'learning_rate': 0.2545552915302118, 'gamma': 0.08946175461396641, 'subsample': 0.9870544572346529, 'colsample_bytree': 0.4265313884329111, 'colsample_bylevel': 0.6806675513583059, 'colsample_bynode': 0.43423490637852236, 'reg_alpha': 0.07225492770028799, 'reg_lambda': 0.016396151371552675, 'max_depth': 5, 'min_child_weight': 13}. Best is trial 42 with value: 1.0442223333333331.
# [I 2025-05-10 18:56:33,424] Trial 62 pruned. Trial was pruned at iteration 120.
# [I 2025-05-10 18:56:37,167] Trial 60 finished with value: 1.0451446666666666 and parameters: {'learning_rate': 0.2590121426270376, 'gamma': 0.025832530375631123, 'subsample': 0.9605557097605656, 'colsample_bytree': 0.43158499131490824, 'colsample_bylevel': 0.8452732900052015, 'colsample_bynode': 0.4386204950108628, 'reg_alpha': 0.06450888991510059, 'reg_lambda': 0.018158530111744578, 'max_depth': 5, 'min_child_weight': 13}. Best is trial 42 with value: 1.0442223333333331.
# [I 2025-05-10 18:56:38,104] Trial 69 pruned. Trial was pruned at iteration 60.
# [I 2025-05-10 18:56:40,921] Trial 71 pruned. Trial was pruned at iteration 30.
# [I 2025-05-10 18:56:41,372] Trial 58 finished with value: 1.0445726666666666 and parameters: {'learning_rate': 0.2525467502776438, 'gamma': 0.0034152152630226034, 'subsample': 0.959227296141926, 'colsample_bytree': 0.4347366696513733, 'colsample_bylevel': 0.8497062680688162, 'colsample_bynode': 0.42865627107585047, 'reg_alpha': 0.07819972851351693, 'reg_lambda': 0.029480932485830256, 'max_depth': 5, 'min_child_weight': 13}. Best is trial 42 with value: 1.0442223333333331.
# [I 2025-05-10 18:56:41,839] Trial 63 finished with value: 1.0459623333333334 and parameters: {'learning_rate': 0.22968896407435865, 'gamma': 0.03457272041573305, 'subsample': 0.8873654931664772, 'colsample_bytree': 0.4302104052560926, 'colsample_bylevel': 0.6690847765072357, 'colsample_bynode': 0.4352825331707316, 'reg_alpha': 0.06900582347212741, 'reg_lambda': 0.014117867115394504, 'max_depth': 5, 'min_child_weight': 13}. Best is trial 42 with value: 1.0442223333333331.
# [I 2025-05-10 18:56:42,012] Trial 70 pruned. Trial was pruned at iteration 60.
# [I 2025-05-10 18:56:44,361] Trial 74 pruned. Trial was pruned at iteration 30.
# [I 2025-05-10 18:56:44,611] Trial 66 finished with value: 1.0450546666666665 and parameters: {'learning_rate': 0.2535081935923537, 'gamma': 0.05083041341897798, 'subsample': 0.964074649120938, 'colsample_bytree': 0.7155980086274191, 'colsample_bylevel': 0.6812810285419774, 'colsample_bynode': 0.4292796184405577, 'reg_alpha': 0.0006000043523353642, 'reg_lambda': 0.0010729308462657948, 'max_depth': 5, 'min_child_weight': 11}. Best is trial 42 with value: 1.0442223333333331.
# [I 2025-05-10 18:56:47,323] Trial 64 finished with value: 1.044015 and parameters: {'learning_rate': 0.2559316879413613, 'gamma': 0.0170582156011843, 'subsample': 0.7370640754301307, 'colsample_bytree': 0.7111699226625902, 'colsample_bylevel': 0.7663187661107388, 'colsample_bynode': 0.43149190499383683, 'reg_alpha': 0.06384713352305776, 'reg_lambda': 0.011160509154321107, 'max_depth': 5, 'min_child_weight': 13}. Best is trial 64 with value: 1.044015.
# [I 2025-05-10 18:56:49,212] Trial 77 pruned. Trial was pruned at iteration 30.
# [I 2025-05-10 18:56:50,729] Trial 72 pruned. Trial was pruned at iteration 120.
# [I 2025-05-10 18:56:54,328] Trial 67 finished with value: 1.0437360000000002 and parameters: {'learning_rate': 0.2598141367425207, 'gamma': 0.004034074552327353, 'subsample': 0.9596990286289616, 'colsample_bytree': 0.4368453505623297, 'colsample_bylevel': 0.7658374229621213, 'colsample_bynode': 0.6401268211947062, 'reg_alpha': 0.06714277350079305, 'reg_lambda': 3.576506948180444e-05, 'max_depth': 5, 'min_child_weight': 9}. Best is trial 67 with value: 1.0437360000000002.
# [I 2025-05-10 18:56:57,656] Trial 68 finished with value: 1.0435943333333333 and parameters: {'learning_rate': 0.2663168266828429, 'gamma': 0.00012228799874032178, 'subsample': 0.975785021283209, 'colsample_bytree': 0.43193415354619985, 'colsample_bylevel': 0.7694451123031512, 'colsample_bynode': 0.4208481992947417, 'reg_alpha': 0.2982390970301194, 'reg_lambda': 0.013584754665458316, 'max_depth': 5, 'min_child_weight': 13}. Best is trial 68 with value: 1.0435943333333333.
# [I 2025-05-10 18:56:59,124] Trial 73 finished with value: 1.044723 and parameters: {'learning_rate': 0.260859508561495, 'gamma': 0.027903157625698363, 'subsample': 0.9163474192911432, 'colsample_bytree': 0.4751974555667752, 'colsample_bylevel': 0.9122982150196817, 'colsample_bynode': 0.4927155573586295, 'reg_alpha': 0.18404921102381738, 'reg_lambda': 9.137576013875675e-05, 'max_depth': 4, 'min_child_weight': 11}. Best is trial 68 with value: 1.0435943333333333.
# [I 2025-05-10 18:57:02,243] Trial 76 finished with value: 1.044473 and parameters: {'learning_rate': 0.204286309522538, 'gamma': 0.03313085378409634, 'subsample': 0.8468545474401434, 'colsample_bytree': 0.723485570573273, 'colsample_bylevel': 0.8284360537970433, 'colsample_bynode': 0.5588815120229351, 'reg_alpha': 0.003641420127170972, 'reg_lambda': 4.289588004816726e-05, 'max_depth': 6, 'min_child_weight': 11}. Best is trial 68 with value: 1.0435943333333333.
# [I 2025-05-10 18:57:04,464] Trial 75 finished with value: 1.0440623333333334 and parameters: {'learning_rate': 0.1702622195414462, 'gamma': 0.014064062984188639, 'subsample': 0.8476847447190221, 'colsample_bytree': 0.4752434219771835, 'colsample_bylevel': 0.9089145702514971, 'colsample_bynode': 0.559911548192367, 'reg_alpha': 0.0036700456824335617, 'reg_lambda': 0.007093314830966933, 'max_depth': 4, 'min_child_weight': 11}. Best is trial 68 with value: 1.0435943333333333.
# [I 2025-05-10 18:57:04,618] Trial 83 pruned. Trial was pruned at iteration 60.
# [I 2025-05-10 18:57:04,824] Trial 78 finished with value: 1.0443740000000001 and parameters: {'learning_rate': 0.20744598158968208, 'gamma': 0.03226134302485478, 'subsample': 0.7567862523038239, 'colsample_bytree': 0.7346094690827327, 'colsample_bylevel': 0.815560701749846, 'colsample_bynode': 0.45386692420178854, 'reg_alpha': 1.291442121149518e-05, 'reg_lambda': 5.3658966334576546e-05, 'max_depth': 5, 'min_child_weight': 12}. Best is trial 68 with value: 1.0435943333333333.
# [I 2025-05-10 18:57:08,113] Trial 82 pruned. Trial was pruned at iteration 120.
# [I 2025-05-10 18:57:10,053] Trial 85 pruned. Trial was pruned at iteration 30.
# [I 2025-05-10 18:57:10,327] Trial 79 finished with value: 1.0444076666666666 and parameters: {'learning_rate': 0.21380672622691013, 'gamma': 0.030579166564868587, 'subsample': 0.6830851997512153, 'colsample_bytree': 0.712636608593993, 'colsample_bylevel': 0.828158778170047, 'colsample_bynode': 0.42422412224468753, 'reg_alpha': 0.0002967420821245548, 'reg_lambda': 0.03121234457029348, 'max_depth': 6, 'min_child_weight': 12}. Best is trial 68 with value: 1.0435943333333333.
# [I 2025-05-10 18:57:13,043] Trial 89 pruned. Trial was pruned at iteration 30.
# [I 2025-05-10 18:57:13,435] Trial 84 pruned. Trial was pruned at iteration 120.
# [I 2025-05-10 18:57:15,650] Trial 86 pruned. Trial was pruned at iteration 120.
# [I 2025-05-10 18:57:15,900] Trial 87 pruned. Trial was pruned at iteration 120.
# [I 2025-05-10 18:57:16,021] Trial 92 pruned. Trial was pruned at iteration 30.
# [I 2025-05-10 18:57:18,544] Trial 94 pruned. Trial was pruned at iteration 30.
# [I 2025-05-10 18:57:18,592] Trial 93 pruned. Trial was pruned at iteration 30.
# [I 2025-05-10 18:57:18,798] Trial 88 pruned. Trial was pruned at iteration 120.
# [I 2025-05-10 18:57:19,166] Trial 95 pruned. Trial was pruned at iteration 30.
# [I 2025-05-10 18:57:21,333] Trial 90 pruned. Trial was pruned at iteration 120.
# [I 2025-05-10 18:57:21,457] Trial 80 finished with value: 1.0438203333333334 and parameters: {'learning_rate': 0.21379053627037808, 'gamma': 0.0007497916606634125, 'subsample': 0.7265219939874704, 'colsample_bytree': 0.756647138456047, 'colsample_bylevel': 0.8635395879485828, 'colsample_bynode': 0.5596319346102285, 'reg_alpha': 0.004343255877557188, 'reg_lambda': 0.0014870216733461393, 'max_depth': 6, 'min_child_weight': 12}. Best is trial 68 with value: 1.0435943333333333.
# [I 2025-05-10 18:57:21,604] Trial 81 finished with value: 1.0433993333333333 and parameters: {'learning_rate': 0.2042624465441571, 'gamma': 0.01087589449309441, 'subsample': 0.731998821369567, 'colsample_bytree': 0.7343176177850355, 'colsample_bylevel': 0.7800491884092193, 'colsample_bynode': 0.705853398401996, 'reg_alpha': 0.0036600015711016677, 'reg_lambda': 0.033146909991156666, 'max_depth': 6, 'min_child_weight': 12}. Best is trial 81 with value: 1.0433993333333333.
# [I 2025-05-10 18:57:21,772] Trial 98 pruned. Trial was pruned at iteration 30.
# [I 2025-05-10 18:57:23,839] Trial 91 pruned. Trial was pruned at iteration 120.
# [I 2025-05-10 18:57:23,945] Trial 97 pruned. Trial was pruned at iteration 60.
# [I 2025-05-10 18:57:24,648] Trial 101 pruned. Trial was pruned at iteration 30.
# [I 2025-05-10 18:57:24,742] Trial 96 pruned. Trial was pruned at iteration 60.
# [I 2025-05-10 18:57:25,237] Trial 99 pruned. Trial was pruned at iteration 60.
# [I 2025-05-10 18:57:26,653] Trial 102 pruned. Trial was pruned at iteration 60.
# [I 2025-05-10 18:57:26,978] Trial 100 pruned. Trial was pruned at iteration 60.
# [I 2025-05-10 18:57:27,117] Trial 103 pruned. Trial was pruned at iteration 60.
# [I 2025-05-10 18:57:27,521] Trial 105 pruned. Trial was pruned at iteration 30.
# [I 2025-05-10 18:57:28,202] Trial 106 pruned. Trial was pruned at iteration 30.
# [I 2025-05-10 18:57:29,741] Trial 107 pruned. Trial was pruned at iteration 30.
# [I 2025-05-10 18:57:30,620] Trial 104 pruned. Trial was pruned at iteration 60.
# [I 2025-05-10 18:57:30,934] Trial 108 pruned. Trial was pruned at iteration 60.
# [I 2025-05-10 18:57:31,429] Trial 109 pruned. Trial was pruned at iteration 30.
# [I 2025-05-10 18:57:33,665] Trial 112 pruned. Trial was pruned at iteration 30.
# [I 2025-05-10 18:57:39,057] Trial 113 pruned. Trial was pruned at iteration 120.
# [I 2025-05-10 18:57:41,138] Trial 116 pruned. Trial was pruned at iteration 120.
# [I 2025-05-10 18:57:41,238] Trial 115 pruned. Trial was pruned at iteration 120.
# [I 2025-05-10 18:57:41,985] Trial 110 finished with value: 1.0458843333333334 and parameters: {'learning_rate': 0.1911856722050459, 'gamma': 0.12116115318324214, 'subsample': 0.7098372007565931, 'colsample_bytree': 0.8170760622255324, 'colsample_bylevel': 0.8905330142998967, 'colsample_bynode': 0.7155001347839409, 'reg_alpha': 0.04278561400420675, 'reg_lambda': 0.031558297137588766, 'max_depth': 4, 'min_child_weight': 13}. Best is trial 81 with value: 1.0433993333333333.
# [I 2025-05-10 18:57:43,981] Trial 111 finished with value: 1.0455910000000002 and parameters: {'learning_rate': 0.2435876638496421, 'gamma': 0.11221669710658548, 'subsample': 0.7034225204459555, 'colsample_bytree': 0.8131727059471334, 'colsample_bylevel': 0.8882240357240447, 'colsample_bynode': 0.41403472817147624, 'reg_alpha': 0.0002194494296948491, 'reg_lambda': 0.022978495837788875, 'max_depth': 4, 'min_child_weight': 13}. Best is trial 81 with value: 1.0433993333333333.
# [I 2025-05-10 18:57:46,130] Trial 114 finished with value: 1.0461123333333333 and parameters: {'learning_rate': 0.19128112721409585, 'gamma': 0.1284969879991649, 'subsample': 0.7486805313796017, 'colsample_bytree': 0.7843733425834444, 'colsample_bylevel': 0.7250894416799356, 'colsample_bynode': 0.4148123039107176, 'reg_alpha': 0.016954451536368636, 'reg_lambda': 0.021931580348048242, 'max_depth': 4, 'min_child_weight': 13}. Best is trial 81 with value: 1.0433993333333333.
# [I 2025-05-10 18:57:47,835] Trial 117 finished with value: 1.046 and parameters: {'learning_rate': 0.19173753504066554, 'gamma': 0.12082018830660607, 'subsample': 0.7510955007348461, 'colsample_bytree': 0.44390660630844603, 'colsample_bylevel': 0.7112020953263589, 'colsample_bynode': 0.41327984125615785, 'reg_alpha': 0.0002077103249120195, 'reg_lambda': 0.011968251145078632, 'max_depth': 5, 'min_child_weight': 11}. Best is trial 81 with value: 1.0433993333333333.
# [I 2025-05-10 18:57:53,498] Trial 125 pruned. Trial was pruned at iteration 60.
# [I 2025-05-10 18:57:57,065] Trial 119 finished with value: 1.0454956666666668 and parameters: {'learning_rate': 0.19254137138398167, 'gamma': 0.07379297319714045, 'subsample': 0.6417250741528785, 'colsample_bytree': 0.46579699949412473, 'colsample_bylevel': 0.7019639080592859, 'colsample_bynode': 0.4043781586553585, 'reg_alpha': 0.022353456269103445, 'reg_lambda': 5.9746162390680554e-05, 'max_depth': 6, 'min_child_weight': 11}. Best is trial 81 with value: 1.0433993333333333.
# [I 2025-05-10 18:57:57,343] Trial 118 finished with value: 1.0438163333333332 and parameters: {'learning_rate': 0.1918293297560052, 'gamma': 0.01590505570623878, 'subsample': 0.7491527039357776, 'colsample_bytree': 0.727167519882117, 'colsample_bylevel': 0.9609592507854177, 'colsample_bynode': 0.4204602976906309, 'reg_alpha': 0.0021781432850030893, 'reg_lambda': 6.497382234169263e-05, 'max_depth': 6, 'min_child_weight': 11}. Best is trial 81 with value: 1.0433993333333333.
# [I 2025-05-10 18:58:02,927] Trial 122 finished with value: 1.0457053333333333 and parameters: {'learning_rate': 0.2786798045893541, 'gamma': 0.019518831513879786, 'subsample': 0.6757064452638861, 'colsample_bytree': 0.44213237186928306, 'colsample_bylevel': 0.701282744129134, 'colsample_bynode': 0.5444086362968685, 'reg_alpha': 0.10633896884628932, 'reg_lambda': 0.01146918991545822, 'max_depth': 5, 'min_child_weight': 11}. Best is trial 81 with value: 1.0433993333333333.
# [I 2025-05-10 18:58:03,475] Trial 120 finished with value: 1.0435283333333334 and parameters: {'learning_rate': 0.19332067848205767, 'gamma': 0.008375858812676783, 'subsample': 0.9815164913217329, 'colsample_bytree': 0.7265932358301735, 'colsample_bylevel': 0.8044455478394378, 'colsample_bynode': 0.40070769131152545, 'reg_alpha': 0.0002962204762593849, 'reg_lambda': 1.0756151024182111e-05, 'max_depth': 6, 'min_child_weight': 11}. Best is trial 81 with value: 1.0433993333333333.
# [I 2025-05-10 18:58:04,089] Trial 123 finished with value: 1.0438353333333332 and parameters: {'learning_rate': 0.20099308002242183, 'gamma': 0.01339631733137768, 'subsample': 0.9884363532689653, 'colsample_bytree': 0.7409822564943459, 'colsample_bylevel': 0.8353940751320716, 'colsample_bynode': 0.5414913372112677, 'reg_alpha': 0.0169952800259835, 'reg_lambda': 1.4075441571648605e-05, 'max_depth': 6, 'min_child_weight': 11}. Best is trial 81 with value: 1.0433993333333333.
# [I 2025-05-10 18:58:05,261] Trial 126 finished with value: 1.0443446666666667 and parameters: {'learning_rate': 0.2003053052559358, 'gamma': 0.02644364948280825, 'subsample': 0.9815258592319465, 'colsample_bytree': 0.7219403302078589, 'colsample_bylevel': 0.8322519706216261, 'colsample_bynode': 0.40013997893333103, 'reg_alpha': 0.0069300625983318076, 'reg_lambda': 0.002489261245298562, 'max_depth': 5, 'min_child_weight': 11}. Best is trial 81 with value: 1.0433993333333333.
# [I 2025-05-10 18:58:05,786] Trial 121 finished with value: 1.0435670000000001 and parameters: {'learning_rate': 0.275436100684261, 'gamma': 0.0027182707121770934, 'subsample': 0.9409081619915651, 'colsample_bytree': 0.7268778422524054, 'colsample_bylevel': 0.8331617059685027, 'colsample_bynode': 0.4005115080721561, 'reg_alpha': 0.020029709829956475, 'reg_lambda': 6.172779681858393e-05, 'max_depth': 6, 'min_child_weight': 11}. Best is trial 81 with value: 1.0433993333333333.
# [I 2025-05-10 18:58:06,355] Trial 124 finished with value: 1.043538 and parameters: {'learning_rate': 0.1620911549220417, 'gamma': 0.008418995199526186, 'subsample': 0.9841937418767486, 'colsample_bytree': 0.7445541570950299, 'colsample_bylevel': 0.7059447219006194, 'colsample_bynode': 0.7757155395891668, 'reg_alpha': 0.006228770909239526, 'reg_lambda': 5.429656019107754e-05, 'max_depth': 6, 'min_child_weight': 11}. Best is trial 81 with value: 1.0433993333333333.
# [I 2025-05-10 18:58:06,641] Trial 127 finished with value: 1.0451883333333332 and parameters: {'learning_rate': 0.2726374855013059, 'gamma': 0.03725010029550764, 'subsample': 0.8200233798364982, 'colsample_bytree': 0.7151500124721114, 'colsample_bylevel': 0.8344295426423584, 'colsample_bynode': 0.7804045624800972, 'reg_alpha': 0.006180574388376079, 'reg_lambda': 1.3292578048180401e-05, 'max_depth': 6, 'min_child_weight': 11}. Best is trial 81 with value: 1.0433993333333333.

# %%
study_xgb.trials_dataframe()
# Out:
#      number     value             datetime_start          datetime_complete  \
# 0         0  1.060148 2025-05-10 18:55:34.294601 2025-05-10 18:55:37.360718
# 1         1  1.056798 2025-05-10 18:55:34.295790 2025-05-10 18:55:39.665239
# 2         2  1.053210 2025-05-10 18:55:34.298171 2025-05-10 18:55:39.026599
# 3         3  1.099273 2025-05-10 18:55:34.298809 2025-05-10 18:55:37.353226
# 4         4  1.061909 2025-05-10 18:55:34.301058 2025-05-10 18:55:38.197869
# ..      ...       ...                        ...                        ...
# 123     123  1.043835 2025-05-10 18:57:43.986001 2025-05-10 18:58:04.089535
# 124     124  1.043538 2025-05-10 18:57:46.132792 2025-05-10 18:58:06.354715
# 125     125  1.048523 2025-05-10 18:57:47.836633 2025-05-10 18:57:53.497755
# 126     126  1.044345 2025-05-10 18:57:53.501050 2025-05-10 18:58:05.261409
# 127     127  1.045188 2025-05-10 18:57:57.073201 2025-05-10 18:58:06.641592
#
#                   duration  params_colsample_bylevel  params_colsample_bynode  \
# 0   0 days 00:00:03.066117                  0.619453                 0.744504
# 1   0 days 00:00:05.369449                  0.419097                 0.494009
# 2   0 days 00:00:04.728428                  0.950396                 0.728489
# 3   0 days 00:00:03.054417                  0.432110                 0.687432
# 4   0 days 00:00:03.896811                  0.978205                 0.627944
# ..                     ...                       ...                      ...
# 123 0 days 00:00:20.103534                  0.835394                 0.541491
# 124 0 days 00:00:20.221923                  0.705945                 0.775716
# 125 0 days 00:00:05.661122                  0.835576                 0.546092
# 126 0 days 00:00:11.760359                  0.832252                 0.400140
# 127 0 days 00:00:09.568391                  0.834430                 0.780405
#
#      params_colsample_bytree  params_gamma  params_learning_rate  \
# 0                   0.455250      3.155444              0.052927
# 1                   0.585941      3.947809              0.280337
# 2                   0.520289      1.998710              0.288687
# 3                   0.871089      2.236638              0.025216
# 4                   0.753282      1.990733              0.043332
# ..                       ...           ...                   ...
# 123                 0.740982      0.013396              0.200993
# 124                 0.744554      0.008419              0.162091
# 125                 0.737406      0.271598              0.275938
# 126                 0.721940      0.026444              0.200305
# 127                 0.715150      0.037250              0.272637
#
#      params_max_depth  params_min_child_weight  params_reg_alpha  \
# 0                   9                       17      1.400882e-02
# 1                   7                        1      4.729810e-05
# 2                   6                       18      1.715692e-02
# 3                  10                       16      8.079612e+00
# 4                  10                        2      7.333269e-07
# ..                ...                      ...               ...
# 123                 6                       11      1.699528e-02
# 124                 6                       11      6.228771e-03
# 125                 6                       12      1.662542e-03
# 126                 5                       11      6.930063e-03
# 127                 6                       11      6.180574e-03
#
#      params_reg_lambda  params_subsample  system_attrs_completed_rung_0  \
# 0         7.573176e-06          0.599214                       1.060148
# 1         1.233926e-06          0.569612                       1.056935
# 2         5.254792e-06          0.968453                       1.053545
# 3         2.074956e-05          0.835226                       1.099273
# 4         1.219932e-07          0.942530                       1.061909
# ..                 ...               ...                            ...
# 123       1.407544e-05          0.988436                       1.045306
# 124       5.429656e-05          0.984194                       1.045736
# 125       7.838037e-05          0.502259                       1.048852
# 126       2.489261e-03          0.981526                       1.045386
# 127       1.329258e-05          0.820023                       1.046101
#
#      system_attrs_completed_rung_1  system_attrs_completed_rung_2     state
# 0                              NaN                            NaN    PRUNED
# 1                         1.056881                            NaN  COMPLETE
# 2                         1.053550                            NaN  COMPLETE
# 3                              NaN                            NaN    PRUNED
# 4                              NaN                            NaN    PRUNED
# ..                             ...                            ...       ...
# 123                       1.044264                       1.043978  COMPLETE
# 124                       1.044333                       1.043757  COMPLETE
# 125                       1.048523                            NaN    PRUNED
# 126                       1.044538                       1.044421  COMPLETE
# 127                       1.045332                       1.045273  COMPLETE
#
# [128 rows x 19 columns]

# %%
temp = study_xgb.best_trial
temp.intermediate_values
# Out:
# {0: 1.173268,
#  1: 1.1251286666666667,
#  2: 1.0965896666666668,
#  3: 1.0790056666666665,
#  4: 1.0673276666666667,
#  5: 1.0598423333333333,
#  6: 1.054681,
#  7: 1.051691,
#  8: 1.0499313333333333,
#  9: 1.0486379999999997,
#  10: 1.0478406666666669,
#  11: 1.0473876666666666,
#  12: 1.047119666666667,
#  13: 1.0469823333333332,
#  14: 1.046796,
#  15: 1.0466893333333334,
#  16: 1.0466866666666668,
#  17: 1.0464719999999998,
#  18: 1.046333,
#  19: 1.0463496666666667,
#  20: 1.0464393333333335,
#  21: 1.0463366666666667,
#  22: 1.0461793333333331,
#  23: 1.0459903333333334,
#  24: 1.0460026666666666,
#  25: 1.045864,
#  26: 1.0457053333333333,
#  27: 1.0456176666666668,
#  28: 1.0455686666666668,
#  29: 1.0455173333333334,
#  30: 1.045447,
#  31: 1.045417,
#  32: 1.0452823333333334,
#  33: 1.0451773333333332,
#  34: 1.0452476666666668,
#  35: 1.045169,
#  36: 1.0450906666666666,
#  37: 1.04509,
#  38: 1.0450766666666667,
#  39: 1.0449873333333333,
#  40: 1.0449353333333333,
#  41: 1.0448973333333333,
#  42: 1.0448450000000002,
#  43: 1.0448033333333333,
#  44: 1.0447870000000001,
#  45: 1.044704,
#  46: 1.0446823333333333,
#  47: 1.0446603333333335,
#  48: 1.04463,
#  49: 1.044665,
#  50: 1.044583,
#  51: 1.0445946666666666,
#  52: 1.0445773333333332,
#  53: 1.0445143333333333,
#  54: 1.0444693333333335,
#  55: 1.0444243333333334,
#  56: 1.044427,
#  57: 1.044354,
#  58: 1.044386,
#  59: 1.0443313333333333,
#  60: 1.0442616666666666,
#  61: 1.0442540000000002,
#  62: 1.0442923333333332,
#  63: 1.044314,
#  64: 1.0443016666666667,
#  65: 1.0442516666666668,
#  66: 1.0442443333333333,
#  67: 1.0442356666666666,
#  68: 1.0441986666666665,
#  69: 1.0442449999999999,
#  70: 1.0442076666666666,
#  71: 1.0441636666666667,
#  72: 1.044117,
#  73: 1.0441263333333335,
#  74: 1.0441269999999998,
#  75: 1.0440826666666667,
#  76: 1.0440379999999998,
#  77: 1.044028,
#  78: 1.044035,
#  79: 1.0440273333333334,
#  80: 1.0440256666666667,
#  81: 1.044021,
#  82: 1.0440263333333333,
#  83: 1.044027,
#  84: 1.0440006666666666,
#  85: 1.0440313333333335,
#  86: 1.0440146666666668,
#  87: 1.0440026666666666,
#  88: 1.0440326666666666,
#  89: 1.044022,
#  90: 1.0440276666666666,
#  91: 1.0439640000000001,
#  92: 1.0439610000000001,
#  93: 1.0439393333333333,
#  94: 1.0439743333333333,
#  95: 1.043879,
#  96: 1.0438560000000001,
#  97: 1.0438263333333333,
#  98: 1.0438349999999998,
#  99: 1.0438316666666665,
#  100: 1.0438483333333333,
#  101: 1.0438496666666666,
#  102: 1.0438043333333333,
#  103: 1.0437926666666668,
#  104: 1.043779,
#  105: 1.0437503333333333,
#  106: 1.04378,
#  107: 1.0438076666666667,
#  108: 1.0437563333333333,
#  109: 1.0437710000000002,
#  110: 1.043743,
#  111: 1.0436923333333334,
#  112: 1.043679,
#  113: 1.0436616666666667,
#  114: 1.043657,
#  115: 1.0436716666666666,
#  116: 1.0436323333333333,
#  117: 1.0437010000000002,
#  118: 1.043671,
#  119: 1.043679,
#  120: 1.0436623333333335,
#  121: 1.0436693333333331,
#  122: 1.0436403333333333,
#  123: 1.0436606666666668,
#  124: 1.043681,
#  125: 1.0436683333333334,
#  126: 1.043691,
#  127: 1.0436686666666666,
#  128: 1.0436723333333333,
#  129: 1.0436423333333333,
#  130: 1.0436423333333333,
#  131: 1.0436436666666669,
#  132: 1.0435876666666666,
#  133: 1.043565,
#  134: 1.0435473333333334,
#  135: 1.0435576666666668,
#  136: 1.0435686666666666,
#  137: 1.0435903333333334,
#  138: 1.0435716666666666,
#  139: 1.0435226666666668,
#  140: 1.0435196666666666,
#  141: 1.0435253333333332,
#  142: 1.0435400000000001,
#  143: 1.0435403333333333,
#  144: 1.0435046666666665,
#  145: 1.0435033333333334,
#  146: 1.043527,
#  147: 1.0435176666666666,
#  148: 1.0434993333333333,
#  149: 1.0435033333333334,
#  150: 1.043512,
#  151: 1.043488,
#  152: 1.0434423333333334,
#  153: 1.0434453333333333,
#  154: 1.0434573333333335,
#  155: 1.0434556666666666,
#  156: 1.0434993333333333,
#  157: 1.0434716666666668,
#  158: 1.0434586666666668,
#  159: 1.0434726666666665,
#  160: 1.0434333333333332,
#  161: 1.043443,
#  162: 1.043440333333333,
#  163: 1.0434280000000002,
#  164: 1.0434083333333335,
#  165: 1.0434166666666667,
#  166: 1.043449,
#  167: 1.0434933333333334,
#  168: 1.0435156666666667,
#  169: 1.0434923333333332,
#  170: 1.0434736666666666,
#  171: 1.043440666666667,
#  172: 1.0434373333333333,
#  173: 1.0434266666666667,
#  174: 1.043426,
#  175: 1.0434386666666668,
#  176: 1.043419,
#  177: 1.0434056666666667,
#  178: 1.0433993333333333,
#  179: 1.04342,
#  180: 1.043444,
#  181: 1.043437,
#  182: 1.0434643333333333,
#  183: 1.043418,
#  184: 1.0434293333333333,
#  185: 1.0434436666666667,
#  186: 1.043427333333333,
#  187: 1.0434296666666667,
#  188: 1.0434263333333333,
#  189: 1.0434506666666667,
#  190: 1.043455,
#  191: 1.0434573333333335,
#  192: 1.043474,
#  193: 1.0434913333333333,
#  194: 1.043523,
#  195: 1.0434876666666668,
#  196: 1.0434676666666667,
#  197: 1.0434836666666667,
#  198: 1.043476,
#  199: 1.0434910000000002}
